# %% [markdown]
# <a href="https://colab.research.google.com/github/Sbarbagnem/AdvancedProject/blob/master/train_model_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mount google drive for access data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
COLAB_PATH = '../drive/My Drive/Laurea Magistrale/Tesi'

# %% [markdown]
# # Clone repo from github

# %%
# %rm -r User_Identify_Inertial_Sensor/
! git clone https://github.com/Sbarbagnem/User_Identify_Inertial_Sensor.git

# %%
# %cd User_Identify_Inertial_Sensor
# Out:
# /content/User_Identify_Inertial_Sensor

# %%
# %cd ..
# Out:
# /content

# %%
# %matplotlib inline
! pip install transforms3d
# Out:
# ...
#      |████████████████████████████████| 71kB 2.1MB/s
# ...
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-cp36-none-any.whl size=59374 sha256=e4b74739474b97a5cbd6c457c3d078940317a62bfc5c7723ae5cc9d240ec4c70
#   Stored in directory: /root/.cache/pip/wheels/3d/3c/84/28d36677f3c760c048bd02b5a547ea0c4027770cc9cdb9af1e
# Successfully built transforms3d
# ...

# %% [markdown]
# # UNIMIB

# %% [markdown]
# ## Example distribution train and test set

# %%
# %run train_model_classification.py -p 1 -t 0 -dataset unimib -fold_val 0 1 -fold_test 2 -run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# ## Magnitude / no magnitude

# %% [markdown]
# #### No magnitude

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 1 -fold_test 2 -magnitude 0 -run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 3)
# Shape train data after deleted overlap sequence:  (4420, 100, 3)
# Shape val data:  (1728, 100, 3)
# Shape test data:  (866, 100, 3)
# using model:  resnet18_2D
# Model: "res_net18single_branch"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              multiple                  192
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 3, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 3, 64)         137088
# ...

# %% [markdown]
# #### Magnitude

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 1 -fold_test 2 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_13 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# ## Different weight method

# %% [markdown]
# ### Weight random

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_26 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_26 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -drop_factor 0.25

# %% [markdown]
# ### Weight balance

# %% [markdown]
# #### Based on act

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w balance -wbo act
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_39 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_39 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# #### Based on subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w balance -wbo subject
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_52 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_52 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# #### Based on act and subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w balance -wbo act_subject
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_65 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_65 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# ### Weight like train set

# %% [markdown]
# #### Weighted based on act

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w train_set -wbo act
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_78 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_78 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# #### Weighted based on subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w train_set -wbo subject
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_91 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_91 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# #### Weighted based on act_subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -fold_val 0 -magnitude 1 -run_colab 1 -colab_path '{COLAB_PATH}' -w train_set -wbo act_subject
# Out:
# Shape train data before delete overlap sequence:  (7733, 100, 4)
# Shape train data after deleted overlap sequence:  (6145, 100, 4)
# Shape test data:  (871, 100, 4)
# using model:  resnet18_2D
# Model: "res_net18single_branch_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_104 (Conv2D)          multiple                  192
# _________________________________________________________________
# batch_normalization_104 (Bat multiple                  128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# #### Function to apply: jitter, scaling, random_sampling, permutation, time_warp, magnitude_warp, rotation.
# #### Number of random function to apply on every sequence: 3
# #### Compose: no

# %%
# %run train_model_classification.py -p 0 -t 1 -a 1 -ap random_transformations -pa 0 -dataset unimib -ratio 5 -fold_val 0 1 -fold_test 2 \
-aug_function jitter scaling random_sampling permutation time_warp magnitude_warp rotation -n_func_to_apply 3 \
-run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
#
#  apply random transformations
#
# data before augmented 4420, data after augmented 59940
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# #### Function to apply: jitter, scaling, random_sampling, permutation, time_warp, magnitude_warp, rotation.
# #### Number of random function to apply on every sequence: 3
# #### Compose: yes

# %%
# %run train_model_classification.py -p 0 -t 1 -a 1 -ap random_transformations -pa 0 -dataset unimib -ratio 5 -fold_val 0 1 -fold_test 2 \
-aug_function jitter scaling random_sampling permutation time_warp magnitude_warp rotation -n_func_to_apply 3 -compose 1 \
-run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
#
#  apply random transformations
#
# data before augmented 4420, data after augmented 59940
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# #### Function to apply: jitter, scaling, random_sampling, permutation, time_warp, magnitude_warp.
# #### Number of random function to apply on every sequence: 3
# #### Compose: no

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -ratio 5 -fold_val 0 1 -fold_test 2 \
-a 1 -ap random_transformations -pa 0 -aug_function jitter scaling random_sampling permutation time_warp magnitude_warp -n_func_to_apply 3 \
-run_colab 1 -colab_path '{COLAB_PATH}' \
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
#
#  apply random transformations
#
# data before augmented 4420, data after augmented 59940
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# #### Function to apply: jitter, scaling, random_sampling, permutation, time_warp, magnitude_warp.
# #### Number of random function to apply on every sequence: 3
# #### Compose: yes

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -ratio 5 -fold_val 0 1 -fold_test 2 \
-a 1 -ap random_transformations -pa 0 -aug_function jitter scaling random_sampling permutation time_warp magnitude_warp -n_func_to_apply 3 -compose 1 \
-run_colab 1 -colab_path '{COLAB_PATH}' \
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
#
#  apply random transformations
#
# data before augmented 4420, data after augmented 59940
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# #### Function to apply: jitter, scaling, random_sampling, permutation, time_warp, magnitude_warp.
# #### Number of random function to apply on every sequence: 3
# #### Only compose: yes

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset unimib -ratio 5 -fold_val 0 1 -fold_test 2 \
-a 1 -ap random_transformations -pa 0 -aug_function jitter scaling random_sampling permutation time_warp magnitude_warp -n_func_to_apply 3 -only_compose 1 \
-run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (6010, 100, 4)
# Shape train data after deleted overlap sequence:  (4420, 100, 4)
# Shape val data:  (1728, 100, 4)
# Shape test data:  (866, 100, 4)
#
#  apply random transformations
#
# data before augmented 4420, data after augmented 59940
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# # SBHAR

# %% [markdown]
# ### Example distribution train and test set

# %%
# %run train_model_classification.py -p 1 -t 0 -dataset sbhar -fold_val 0
# Out:
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:661: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(r, c, 1)
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:672: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# ## No aug
# * Init_lr = 0.001
# * Drop_factor = 0.25
# * Epoch_drop = 20

# %% [markdown]
# ### Weight random

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# Model: "res_net18single_branch"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              multiple                  192
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# ...

# %% [markdown]
# ### Weight balance

# %% [markdown]
# #### Based on act

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w balance -wbo act
# Out:
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# Model: "res_net18single_branch_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_13 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 8, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 8, 64)         137088
# _________________________________________________________________
# ...

# %% [markdown]
# #### Based on subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w balance -wbo subject
# Out:
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# Model: "res_net18single_branch_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_26 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_26 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 8, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 8, 64)         137088
# _________________________________________________________________
# ...

# %% [markdown]
# #### Based on act and subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w balance -wbo act_subject

# %% [markdown]
# ### Weight like train set

# %% [markdown]
# #### Weighted based on act

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w train_set -wbo act
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# Model: "res_net18single_branch"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              multiple                  192
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# ...

# %% [markdown]
# #### Weighted based on subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w train_set -wbo subject
# Out:
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
# Model: "res_net18single_branch_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_13 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 8, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 8, 64)         137088
# _________________________________________________________________
# ...

# %% [markdown]
# #### Weighted based on act_subject

# %%
# %run train_model_classification.py -p 0 -t 1 -dataset sbhar -fold_val 0 -init_lr 0.001 -drop_factor 0.25 -drop_epoch 20 -w train_set -wbo act_subject

# %% [markdown]
# ## Aug

# %%
# %run train_model_classification.py -p 0 -t 1 -a 1 -ap random_transformations -pa 0 -dataset sbhar -ratio 2 -fold_val 0 -w train_set -wbo act \
-aug_function jitter scaling random_sampling permutation time_warp magnitude_warp -n_func_to_apply 3
# Out:
# Shape train data before delete overlap sequence:  (14178, 100, 8)
# Shape train data after deleted overlap sequence:  (11514, 100, 8)
# Shape test data:  (1575, 100, 8)
#
#  apply random transformations
#
# data before augmented 11514, data after augmented 106794
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:672: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(r, c, 1)
# ...

# %% [markdown]
# # SBHAR 6 ADL

# %% [markdown]
# #### Accelerometer and gyroscope

# %%
# %run train_model_classification.py -p 1 -t 1 -dataset sbhar_six_adl -fold_val 0 1 -fold_test 2 -run_colab 1 -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (10277, 100, 8)
# Shape train data after deleted overlap sequence:  (7389, 100, 8)
# Shape val data:  (2933, 100, 8)
# Shape test data:  (1467, 100, 8)
# /content/User_Identify_Inertial_Sensor/model/custom_model.py:712: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(row, col, 1)
# ...

# %% [markdown]
# #### Six-adl only accelerometer

# %%
# %run train_model_classification.py -p false -t true -dataset sbhar_six_adl -fold_val 0 1 -fold_test 2 -run_colab true -only_acc true -colab_path '{COLAB_PATH}'
# Out:
# Shape train data before delete overlap sequence:  (10277, 100, 8)
# Shape train data after deleted overlap sequence:  (7389, 100, 8)
# Shape val data:  (2933, 100, 8)
# Shape test data:  (1467, 100, 8)
# using model:  resnet18_2D
# Model: "res_net18single_branch_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_52 (Conv2D)           multiple                  192
# _________________________________________________________________
# batch_normalization_52 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 multiple                  0
# _________________________________________________________________
# residual_block_1 (Sequential (None, 47, 4, 32)         39872
# _________________________________________________________________
# residual_block_2 (Sequential (None, 47, 4, 64)         137088
# ...
